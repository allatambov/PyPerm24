# %% [markdown]
# # Анализ данных в Python
#
# *Алла Тамбовцева*
#
# ## Лабораторная работа 6
#
# ### Формат сдачи
#
# За разные задачи можно получить разное число баллов. Чтобы получить оценку 10, нужно предложить корректное решение всех задач.
#
# Для сдачи домашнего задания необходимо скачать текущий ipynb-файл, вписать в него свои решения, сохранить изменения и загрузить обновленный файл на Dropbox по предложенной на странице курса ссылке. Иметь аккаунт Dropbox для этого не требуется, достаточно пройти по ссылке и выбрать файл на компьютере. Получить ipynb-файл можно, выбрав в Jupyter пункт меню *File → Download as... → Notebook (.ipynb)*.

# %% [markdown]
# ## Часть 1. Работаем с долями (4 балла)
#
# В файле `store.csv` сохранены данные о поведении пользователей сайта некоторого продуктового онлайн-магазина.
#
# * `RecordID`: id записи;
# * `IP Address`: IP-адрес пользователя;
# * `LoggedInFlag`: залогинен ли пользователь на сайте или нет (1 или 0);
# * `ServerID`: id сервера, на котором хранится версия сайта (1 – версия с новым дизайном, 2 и 3 – версия с текущим дизайном).
# * `VisitPageFlag`: перешел ли пользователь на страницу программы лояльности или нет (1 или 0).
#
# Глобальная задача – понять, правда ли, что новый дизайн сайта (с новым оформлением и расположением ссылки для перехода на страницу программы лояльности) приводит к увеличению конверсии – процента пользователей, перешедших на страницу программу лояльности.

# %% [markdown]
# ### Задача 1 (0.5 балла). Загружаем данные
#
# Загрузите данные из [файла](https://raw.githubusercontent.com/allatambov/PyPerm24/main/store.csv) `store.csv` и сохраните их в датафрейм. Добавьте в датафрейм столбец `Group` со следующими значениями:
#
# * `New` : если значение `ServerID` равно 1;
# * `Old`: если значение `ServerID` равно 2 или 3.
#
# Выберите из датафрейма строки, соответствующие пользователям, которые не залогинены на сайте магазина, и сохраните их в отдельный датафрейм `chosen`.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 2 (1 балл). Строим столбиковую диаграмму
#
# Постройте, используя возможности библиотеки `seaborn` и датафрейм `chosen`, столбиковую диаграмму, которая показывает, сколько пользователей кликнуло/не кликнуло на страницу программы лояльности среди тех, кто попал на текущую версию сайта (`Old`) и среди тех, кто попал на новую версию сайта (`New`). Должна получиться одна столбиковая диаграмма с двумя группами из двух столбцов (все четыре столбца в одних осях). Измените цвета заливки столбцов, добавьте заголовок диаграммы.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 3 (0.5 балла). Вычисляем проценты
#
# Вычислите процент пользователей, которые кликнули/не кликнули на страницу программы лояльности среди тех, кто попал на текущую версию сайта (`Old`) и среди тех, кто попал на новую версию сайта (`New`). Должна получиться таблица (или иная выдача) из четырёх значений.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 4 (2 балла). Проверяем гипотезу
#
# Используя подходящий статистический критерий, проверьте, приняв уровень значимости 5%, можно ли считать, что новый дизайн сайта даёт более высокую конверсию – более высокую долю незалогиненных пользователей, которые кликнули на соответствующую ссылку и перешли на страницу программы лояльности.
#
# Помимо кода, укажите:
#
# * название используемого теста;
# * нулевую и альтернативную гипотезу (альтернативную гипотезу выберите одностороннюю, её направление – исходя из данных);
# * вывод, из которого можно однозначно понять, конверсия сайта в новом дизайне выше или нет.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ## Часть 2. Работаем со средними/медианами (6 баллов)

# %% [markdown]
# В [файле](https://raw.githubusercontent.com/allatambov/PyPerm24/main/Diets.csv) `Diets.csv` хранится информация об испытуемых, которые тестировали три разных вида диеты.
#
# * `Person`: id участника;
# * `gender`: пол участника;
# * `Age`: возраст участника;
# * `Height`: рост участника;
# * `pre.weight`: вес участника до диеты;
# * `Diet`: тип диеты (значения 1, 2, 3);
# * `weight6weeks`: вес участника после 6 недель диеты;
# * `Diff`: разница в весе – сколько килограммов сброшено после 6 недель диеты.
#
# Загрузите данные из файла `diet.csv` и сохраните их в датафрейм `diet`, удалите строки с пропущенными значениями (где хотя бы одно значение пропущено).

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 5 (0.5 балла)
#
# Сгруппируйте данные по типу диеты и выведите на экран таблицу, в которой для каждого типа диеты указаны
#
# * минимальное число сброшенных килограммов;
# * максимальное число сброшенных килограммов;
# * среднее число сброшенных килограммов;
# * медианное число сброшенных килограммов.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 6 (1 балл)
#
# Используя возможности `seaborn`, постройте для каждого типа диеты гистограммы для количества сброшенных килограммов. Три гистограммы должны быть в рамках одного изображения, но в разных окнах (три окна в строке). Прокомментируйте полученные результаты – можно ли считать, что распределение показателя в каждой группе является нормальным или примерно нормальным?

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 7 (0.5 балла)
#
# Используя возможности `seaborn`, постройте для каждого типа диеты ящики с усами для количества сброшенных килограммов. Три ящика с усами должны быть в одних осях, то есть рядом друг с другом в рамках одного графика. Прокомментируйте полученные результаты – можно ли считать, что медианное значение количества сброшенных килограммов отличается в зависимости от типа диеты?

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 8 (2 балла)
#
# Используя подходящий статистический критерий, проверьте, приняв уровень значимости 5%, можно ли считать, что все три диеты одинаково эффективны для сброса веса.
#
# Помимо кода, укажите:
#
# * название используемого теста – и обоснование его выбора;
# * нулевую и альтернативную гипотезу;
# * вывод, из которого можно однозначно понять, есть ли различия или нет.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 9 (2 балла)
#
# Выберите строки, соответствующие двум диетам с наименьшей разницей в среднем/медианном количестве сброшенных килограммов, и сохраните их в датафрейм `two`. Используя подходящий статистический критерий, проверьте, приняв уровень значимости 5%, можно ли считать, что эти две диеты одинаково эффективны для сброса веса.
#
# Помимо кода, укажите:
#
# * название используемого теста – и обоснование его выбора;
# * нулевую и альтернативную гипотезу;
# * вывод, из которого можно однозначно понять, есть ли различия или нет.

# %%
### YOUR CODE HERE ###
