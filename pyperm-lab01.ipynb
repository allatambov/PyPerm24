# %% [markdown]
# # Анализ данных в Python
#
# *Алла Тамбовцева*
#
# ## Лабораторная работа 1

# %% [markdown]
# ## Правила игры
#
# За разные задачи можно получить разное число баллов. Чтобы получить оценку 10, нужно предложить корректное решение всех задач.
#
# Задача считается решенной, если код успешно проходит тесты и не содержит грубых нарушений («подгонка» под тесты, копирование кода другого студента). «Подгонка» под тесты – написание кода не для общего случая, а для соответствия конкретным значениям в ячейке с тестами. Пример: пишем не универсальный код для проверки четности числа, а код, который правильно работает только на числах 2, 5, 8, потому что именно эти числа используются в тестах.
#
# Условия задач повышенной сложности (со звёздочкой) включают ограничения – запрет на использование некоторых конструкций и операторов. Это не искусственное усложнение жизни, это задачи, развивающие алгоритмическое мышление. Умение выполнить задачу с минимальными затратами по времени без лишнего кода с условиями и циклами крупные компании требуют сейчас даже от аналитиков. На собеседовании вполне может встретиться задача на алгоритмы, даже если вы не разработчик, и планируете мирно анализировать и визуализировать данные.
#
# ## Формат сдачи
#
# Для сдачи домашнего задания необходимо скачать текущий ipynb-файл, вписать в него свои решения, сохранить изменения и загрузить обновленный файл на Dropbox по предложенной на странице курса ссылке. Иметь аккаунт Dropbox для этого не требуется, достаточно пройти по ссылке и выбрать файл на компьютере.
#
# Получить ipynb-файл можно, выбрав в Jupyter пункт меню *File → Download as... → Notebook (.ipynb)*.
#
# ## Формат выполнения заданий
#
# Во всех задачах для удобства проверки кода требуется написать функцию. Шаблон для функции уже написан, не меняйте её название, просто впишите свой код вместо `### YOUR CODE HERE` и укажите название переменной с полученным результатом после `return`. Функции во всех задачах не должны ничего выводить на экран, после самопроверки уберите все конструкции с `print()`, если вы их использовали. Пример выполнения и оформления решения – см. задачу 0.

# %% [markdown]
# ## Задание

# %% [markdown]
# ### Задача 0. Пример решения, не оценивается
#
# Напишите функцию `get_size()` , которая принимает на вход размер обуви `size` (целое положительное число) и возвращает размер туфель для скалолазания, учитывая, что обычно размер скальных туфель на два размера меньше обычного.
#
# **Примеры**
#
# На входе:
#
#     37
#
# На выходе:
#
#     35

# %%
def get_size(size):
    
    ### YOUR CODE HERE
    
    return

# %% [markdown]
# Решение:

# %%
def get_size(size):
    
    res = size - 2
    
    return res

# %% [markdown]
# Тесты (если всё верно, не выводится ничего, если ошибка – сообщение о неверном результате):

# %%
assert get_size(36) == 34, "Неверный результат"
assert get_size(38) == 36, "Неверный результат"
assert get_size(40) == 38, "Неверный результат"
assert get_size(37) == 35, "Неверный результат"

# %% [markdown]
# ### Задача 1. Кортеж Его Высочества (1 балл)
#
# Чиполлино попросил медведя, освобождённого им из зоопарка, собрать некоторую информацию о кортеже принца Лимона, который должен проехать вечером по центральной улице, но забыл, что тот не знает, как пишутся цифры. Тогда Чиполлино придумал такую систему обозначений:
#
# * `&` – принц Лимон (носит плащ с длинным «хвостом»);
# * `8` – министры (носят тугие ленты поверх мундира);
# * `0` – придворные лимончики (без лент и плащей).
#
# Так как порядок следования в кортеже строго регламентирован, на первом месте всегда следует принц, далее – министры, а затем уже придворные лимончики. Исходя из этого, у медведя могут получаться записи такого вида: `& 88 0000` (принц, два министра, четверо придворных), `& 8 00000` (принц, министр, пятеро придворных), и так далее.
#
# Напишите функцию `get_info()`, которая запрашивает с клавиатуры строку `inp`, состоящую из символов, описанных выше, и пробелов, и возвращает кортеж из этих символов и чисел, которые соответствуют количеству лимонов, занимающих разные должности.
#
# **Примеры**
#
# На входе:
#
#     "& 8 00000"
#
# На выходе:
#
#     ('&', 1, '8', 1, '0', 5)
#
# На входе:
#
#     "& 88 0000"
#
# На выходе:
#
#     ('&', 1, '8', 2, '0', 4)
#
# На входе:
#
#     "& 888 00"
#
# На выходе:
#
#     ('&', 1, '8', 3, '0', 2)

# %%
def get_info(inp):
    
    ### YOUR CODE HERE
    
    return

# %%
assert get_info("& 888 0") == ('&', 1, '8', 3, '0', 1), "Неверный результат"
assert get_info("& 8 00000") == ('&', 1, '8', 1, '0', 5), "Неверный результат"
assert get_info("& 8 000") == ('&', 1, '8', 1, '0', 3), "Неверный результат"
assert get_info("& 8888 000000") == ('&', 1, '8', 4, '0', 6), "Неверный результат"
assert get_info("& 88 000000") == ('&', 1, '8', 2, '0', 6), "Неверный результат"

# %% [markdown]
# ### Задача 2. Smoke on the water (1 балл)
#
# Напишите функцию `get_smoke()`, которая принимает на вход список значений индекса качества воздуха `values` (целые неотрицательные числа) и возвращает список текстовых комментариев согласно следующим критериям:
#
# * 0–33: Very Good
# * 34–66: Good
# * 67–99: Fair
# * 100–149: Poor
# * 150–200: Very Poor
# * 200+: Hazardous
#
# Уточнения:
#
# * Строки с текстовыми комментариями уже сохранены в переменные `very_good` – `hazardous`.
# * Гарантируется, что в `values` целые неотрицательные числа.
#
# **Пример**
#
# На входе:
#
#     [72, 33, 123, 220]
#
# На выходе:
#
#     ['Fair', 'Very Good', 'Poor', 'Hazardous']

# %%
def get_smoke(values):
    
    very_good = "Very Good"
    good = "Good"
    fair = "Fair"
    poor = "Poor"
    very_poor = "Very Poor"
    hazardous = "Hazardous"
    
    ### YOUR CODE HERE
    
    return

# %%
assert get_smoke([30, 67, 149, 
                  200, 56, 78, 111]) == ['Very Good', 'Fair', 'Poor', 
                                         'Very Poor', 'Good', 'Fair', 'Poor'], "Неверный результат"

assert get_smoke([122, 34, 101, 45, 
                  200, 66, 67, 88, 43]) == ['Poor', 'Good', 'Poor', 'Good', 
                                            'Very Poor', 'Good', 'Fair', 'Fair', 'Good'], "Неверный результат"

assert get_smoke([72, 33, 123, 220]) == ['Fair', 'Very Good', 
                                         'Poor', 'Hazardous'], "Неверный результат"

# %% [markdown]
# ###  Задача 3. На дальней станции сойду... (2 балла)
#
# Дан список станций жёлтой ветки московского метро (упорядочены как на карте):
#
#     line = ["Третьяковская", "Марксистская", "Площадь Ильича", "Авиамоторная", "Шоссе Энтузиастов", "Перово", "Новогиреево", "Новокосино"]
#
# Движение может происходить как от Третьяковской до Новокосино, так и от Новокосино до Третьяковской.
#
# Напишите функцию `get_next()`, которая принимает на вход название текущей станции метро (`name`) и направление движения (`direct`, 1 – от Третьяковской до Новокосино, 2 – наоборот) и возвращает название следующей станции. Если станция конечная, функция должна возвращать значение `Текущая станция конечная`.
#
# **Примеры**
#
# На входе:
#
#     "Площадь Ильича", 1
#
# На выходе:
#
#     "Авиамоторная"
#
# На входе:
#
#     "Площадь Ильича", 2
#
# На выходе:
#
#     "Марксистская"
#
# На входе:
#
#     "Третьяковская", 2
#
# На выходе:
#
#     "Текущая станция конечная"
#
# На входе:
#
#     "Новокосино", 1
#
# На выходе:
#
#     "Текущая станция конечная"

# %%
def get_next(name, direct):
    
    line = ["Третьяковская", "Марксистская", "Площадь Ильича", "Авиамоторная", 
            "Шоссе Энтузиастов", "Перово", "Новогиреево", "Новокосино"]
    
    ### YOUR CODE HERE
    
    return

# %%
assert get_next("Площадь Ильича", 1) == "Авиамоторная", "Неверный результат"
assert get_next("Площадь Ильича", 2) == "Марксистская", "Неверный результат"
assert get_next("Перово", 1) == "Авиамоторная", "Неверный результат"
assert get_next("Третьяковская", 2) == "Текущая станция конечная", "Неверный результат"
assert get_next("Новокосино", 1) == "Текущая станция конечная", "Неверный результат"

# %% [markdown]
# ### Задача 4. Sort it out (1 балл)
#
# В списке `files` сохранены названия файлов с разными расширениями. Напишите функцию `get_sorted()`, которая вернёт список, состоящий только из названий файлов с расширениями `.doc` или `.docx`, отсортированых по алфавиту. Обратите внимание, функция ничего не принимает на вход, список с файлами здесь один конкретный, он внутри.

# %%
def get_info():

    files = ["review.doc", "main.html", "mydoc.docx", "dreams-data.csv", "intro.R", 
         "hw01.tex", "Заявление.docx", "Заявление(копия).docx", "Расписание.xlsx", "Сценарий.doc"]

    ### YOUR CODE HERE
    
    return

# %%
assert get_info() == ['mydoc.docx','review.doc','Заявление(копия).docx',
                'Заявление.docx','Сценарий.doc'], "Проверьте итоговый список"

# %% [markdown]
# ### Задача 5. Добрые дела (2 балла)
#
# Питон Петя решил сделать хорошее дело – раздать те книги, которые у него хранятся в нескольких экземлярах.
#
# Напишите функцию `to_give()`, которая:
#
# * принимает на вход список книг `books` (список строк);
# * возвращает отсортированный по алфавиту список книг, которые нужно отдать, то есть те книги, которые в списке встречаются более одного раза.
#
# **Примеры**
#
# На входе:
#
#     ['Хобби доктора Травена', 'Хобби доктора Травена', 'Змеелов', 'Маленький принц',
#     'Питоны о Питонах. Автобиография', 'Python для детей', 'Питон для детей', 'Кролики и удавы',
#     'Маленький принц', 'Удавы и питоны. Уход и содержание', 'Питон для детей']
#
# На выходе:
#
#     ['Маленький принц', 'Питон для детей', 'Хобби доктора Травена']
#
# На входе:
#
#     ['Змеелов', 'Маленький принц', 'Хобби доктора Травена']
#
# На выходе:
#
#     []

# %%
def to_give(books):
    
    ### YOUR CODE HERE
    
    return

# %%
assert to_give(['Хобби доктора Травена', 
                'Хобби доктора Травена', 
                'Змеелов', 'Маленький принц', 
                'Питоны о Питонах. Автобиография', 
                'Python для детей', 'Питон для детей', 
                'Кролики и удавы', 'Маленький принц', 
                'Удавы и питоны. Уход и содержание', 
                'Питон для детей']) == ['Маленький принц', 'Питон для детей', 
                                        'Хобби доктора Травена'], 'Неверно'

assert to_give(['Змеелов', 'Маленький принц', 'Хобби доктора Травена']) == [], 'Неверно'

assert to_give(['C', 'C', 'D', 'E', 'A', 'A', 'A', 'A']) == ['A', 'C'], 'Неверно'

# %% [markdown]
# ### Задача 6*. Что скрывают звёзды (3 балла)
#
# Напишите функцию `get_star()`, которая угадывает, какая цифра была скрыта за «звёздочкой», если известно, что ей на вход подают сначала одно двузначное число со «звёздочкой» на конце (`one`), затем – второе двузначное число со «звёздочкой» в начале (`two`), а затем их сумму в виде строки (`three`). Считайте, что сумма чисел тоже является двузначным числом.
#
# **NB.** При решении этой задачи нельзя использовать конструкцию `if-else` и  любые способы явной проверки выполнения условий, например, с помощью операторов `>` или `<`.
#
# **Примеры**
#
# Ввод:
#
#     "2*",
#     "*1",
#     "54"
#
# Вывод:
#
#     "* = 3"
#
# Ввод:
#
#     "1*",
#     "*3",
#     "90"
#
# Вывод:
#
#     "* = 7"

# %%
def get_star(one, two, three):
    
    ### YOUR CODE HERE
    
    return

# %%
assert get_star("2*", "*1", "54") == "* = 3", "Неверно"
assert get_star("1*", "*3", "90") == "* = 7", "Неверно"
assert get_star("2*", "*1", "65") == "* = 4", "Неверно"
assert get_star("3*", "*3", "44") == "* = 1", "Неверно"
assert get_star("1*", "*4", "80") == "* = 6", "Неверно"
assert get_star("1*", "*6", "71") == "* = 5", "Неверно"

# %% [markdown]
# *Названия и сюжеты задач:*
#
# *№1: Д.Родари. Приключения Чиполлино.*<br>
# *№2: Deep Purple (Machine Head, 1972)*<br>
# *№3: На дальней станции сойду (музыка – В.Шаинский, стихи – М.Танич, 1976)*
